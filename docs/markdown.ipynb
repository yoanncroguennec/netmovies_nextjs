# %% [markdown]
# Mettre un lien hypertexte :
# Lien cours Origin Cours Markdown : [Lien](https://github.com/YannHY/cours "Cours Markdown").
#
# [Video](https://www.youtube.com/watch?v=g7DpYWR8vqA)
# <b>Mot en gras</b>
#
# Retour à la ligne <br />
#
# # Titre de niveau 1
# ## Titre de niveau 2
# ### Titre de niveau 3
# #### Titre de niveau 4
# ##### Titre de niveau 5
# ###### Titre de niveau 6
#
# Mot en italique, placez ce mot entre deux astérisques * : *italique*.<br />
# Mot en gras, places-le entre deux astérisques ** : **gras**.<br />
# Surligner un mot, placez deux signes égal de part et d’autre : Ce mot est ==surligné==.<br />
# Barrer un mot, encadrez-le d’un double tilde ~~ : Ce mot est ~~barré~~.<br />
#
# Faire une liste ordonnée, simplement numéroter les lignes suivies à chaque fois d’un point :
# 1. Élément 1
# 2. Élément 2
# 3. Élément 3
#
# Faire une liste non-ordonnée (Liste à puces), utiliser au choix le tiret (-), l’astérisque (*) ou le signe +.
# - Élément 1
# - Élément 2
# - Élément 3
#
# * Élément 1
# * Élément 2
# * Élément 3
#
# + Élément 1
# + Élément 2
# + Élément 3
#
#
# * une élément
# * un autre
#     * un sous élément
#     * un autre sous élément
# * un dernier élément
#
# Faire un tableau<br />
# | Aligné à gauche  | Centré          | Aligné à droite |
# | :--------------- |:---------------:| -----:|
# | Aligné à gauche  |   ce texte        |  Aligné à droite |
# | Aligné à gauche  | est             |   Aligné à droite |
# | Aligné à gauche  | centré          |    Aligné à droite |
#
# <br /><br /><br />
#
#
# https://github.com/yoanncroguennec/CoursMarkdown/assets/38597373/3a18764c-2dff-4da8-9323-ce7617dc303e
#
#
# Tableau : Pour aligner le texte à gauche, insèrer :-- dans le deuxième rang. Tandis que pour aligner le texte à droite, insèrer --:. <br />
# [left]Texte àligné à gauche[/left]
# [center]Texte centré[/center]
# [right]Texte algné à droite[/right]
#
# Texte normal suivi d’un [color=#26B260]texte coloré en vert[/color] dans un paragraphe.
# Texte normal suivi d’un <span style="color: #26B260">texte coloré en vert</span> dans un paragraphe.
#
# <br />
# <span style="color:blue">some *blue* text</span>.<br />
#
# Texte normal suivi d’un <span style="color: #26B260">texte coloré en vert</span> dans un paragraphe.<br />
#
#     [fa=firefox /]
#     [fa=firefox extras=fa-2x /]
#     [[fa=firefox extras=fa-3x /] Avec un lien](https://www.mozilla.org/fr/firefox/new/)
#     [fa=firefox extras=fa-4x,fa-spin /]
